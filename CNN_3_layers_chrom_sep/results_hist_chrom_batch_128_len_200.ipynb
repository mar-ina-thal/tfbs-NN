# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
def extract_scores(file_path):
    scores_dict = {}
    
    try:
        df = pd.read_csv(file_path)
        
        # Filter rows based on 'Metric' column
        metrics_df = df[df['Metric'].isin(['valid_f_score', 'valid_auroc'])]

        # Extract values
        valid_f_score = float(metrics_df[metrics_df['Metric'] == 'valid_f_score']['Last_Value'].values[0])
        valid_auroc = float(re.search(r'\d+\.\d+', metrics_df[metrics_df['Metric'] == 'valid_auroc']['Last_Value'].values[0]).group())
        
        return valid_f_score, valid_auroc
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None, None

# %%
import pandas as pd
import re
import numpy as np
import ast

def extract_test_scores(file_path):
    try:
        df = pd.read_csv(file_path)

        # Extract values
        test_f_score = float(df.get('Test F-Score', [0])[0])
        test_auroc = float(re.search(r'\d+\.\d+', df.get('Test AUROC', [0])[0]).group())
        len_dataloader = int(df.get('Len Dataloader', [0])[0])
        confusion_matrix_str = df.get('Test confusion matrix', [''])[0]

        # Print the results
        print(f"Test F-Score: {test_f_score}")
        print(f"Test AUROC: {test_auroc}")
        print(f"Total Length of Dataloader: {len_dataloader}")

        # Print the confusion matrix string before attempting to evaluate it
        print(f"Confusion Matrix String: {confusion_matrix_str}")

        """
        # Convert the confusion matrix string to a numpy array using ast.literal_eval
        confusion_matrix = np.array(ast.literal_eval(confusion_matrix_str))

        # Calculate the percentage of each class in the confusion matrix
        class_percentages = confusion_matrix / confusion_matrix.sum(axis=1, keepdims=True) * 100

        print(f"Confusion Matrix:\n{confusion_matrix}")
        print("Class Percentages in Confusion Matrix:")
        for i, percentage in enumerate(class_percentages):
            print(f"Class {i}: {percentage[0]:.2f}%")
        
        
        """
        
        return test_f_score, test_auroc

    except KeyError as e:
        print(f"Error processing {file_path}: One or more expected columns not found.")
        print(f"Available columns in the DataFrame: {df.columns}")
        return None, None
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None, None

# %%
def process_csv_files(tf_list_path):
    with open(tf_list_path, 'r') as file:
        tf_list = [line.strip() for line in file]

    results_dict = {}
    
    for tf in tf_list:
        base_path = f"/mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/{tf}/CNN3/"
        file_path = os.path.join(base_path, f"test_results.csv")
        
        test_f_score, test_auroc = extract_test_scores(file_path)
        
        if test_f_score is not None and test_auroc is not None:
            results_dict[tf] = {'test_f_score': test_f_score, 'test_auroc': test_auroc}

    return results_dict

# %%
tf_list_path = "/mnt/raid1/thalassini/home/Downloads/target_names_6.txt"
#base_path = f"CNN_results_balanced_kernels_100/{tf}"

results = process_csv_files(tf_list_path)

# tn, fp, fn, tp
# for tf, scores in results.items():
#    print(f"{tf}: Valid F Score = {scores['valid_f_score']}, Valid AUROC = {scores['valid_auroc']}")
# Out:
# Test F-Score: 0.6876677923415014
# Test AUROC: 0.7765
# Total Length of Dataloader: 8827
# Confusion Matrix String: [3434  846 1882 2665]
# Test F-Score: 0.5686642694772082
# Test AUROC: 0.5872
# Total Length of Dataloader: 4596
# Confusion Matrix String: [1000 1039  933 1624]
# Test F-Score: 0.5257868447196176
# Test AUROC: 0.5473
# Total Length of Dataloader: 9262
# Confusion Matrix String: [2421 2184 2209 2448]
# Test F-Score: 0.7443190990940364
# Test AUROC: 0.8301
# Total Length of Dataloader: 9682
# Confusion Matrix String: [4247  513 1911 3011]
# Test F-Score: 0.5620242808139778
# Test AUROC: 0.621
# Total Length of Dataloader: 2903
# Confusion Matrix String: [1087  377  851  588]
# Test F-Score: 0.5097103112314141
# Test AUROC: 0.5384
# Total Length of Dataloader: 10987
# Confusion Matrix String: [2100 3487 1783 3617]
# Test F-Score: 0.5457500543775199
# Test AUROC: 0.5695
# Total Length of Dataloader: 2492
# Confusion Matrix String: [692 902 234 664]
# Test F-Score: 0.5174454060488343
# Test AUROC: 0.5422
# Total Length of Dataloader: 5424
# Confusion Matrix String: [1608  946 1653 1217]
# Test F-Score: 0.60066244573013
# Test AUROC: 0.632
# Total Length of Dataloader: 5115
# Confusion Matrix String: [1938 1158  900 1119]
# Test F-Score: 0.5856026219631807
# Test AUROC: 0.633
# Total Length of Dataloader: 11641
# Confusion Matrix String: [3173 2506 2315 3647]
# Test F-Score: 0.5158403201238384
# Test AUROC: 0.5293
# Total Length of Dataloader: 12847
# Confusion Matrix String: [3648 2659 3540 3000]
# Error processing /mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/GABPA/CNN3/test_results.csv: [Errno 2] No such file or directory: '/mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/GABPA/CNN3/test_results.csv'
# Test F-Score: 0.5173611195168839
# Test AUROC: 0.5162
# Total Length of Dataloader: 5759
# Confusion Matrix String: [1779 1168 1594 1218]
# Test F-Score: 0.5423436350862583
# Test AUROC: 0.5554
# Total Length of Dataloader: 7663
# Confusion Matrix String: [2252 1584 1916 1911]
# Test F-Score: 0.5729485030218062
# Test AUROC: 0.6165
# Total Length of Dataloader: 9096
# Confusion Matrix String: [2964 1546 2294 2292]
# Test F-Score: 0.58717557347909
# Test AUROC: 0.6366
# Total Length of Dataloader: 7273
# Confusion Matrix String: [2276 1337 1661 1999]
# Test F-Score: 0.520523902984386
# Test AUROC: 0.5323
# Total Length of Dataloader: 11440
# Confusion Matrix String: [2947 2668 2822 3003]
# Test F-Score: 0.4998312071312814
# Test AUROC: 0.5145
# Total Length of Dataloader: 5016
# Confusion Matrix String: [1605 1002 1473  936]
# Test F-Score: 0.554371703344312
# Test AUROC: 0.5785
# Total Length of Dataloader: 11507
# Confusion Matrix String: [3542 2225 2882 2858]
# Test F-Score: 0.530301131658055
# Test AUROC: 0.5573
# Total Length of Dataloader: 9883
# Confusion Matrix String: [2531 2665 1969 2718]
# Error processing /mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/RCOR1/CNN3/test_results.csv: [Errno 2] No such file or directory: '/mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/RCOR1/CNN3/test_results.csv'
# Test F-Score: 0.5138866075585347
# Test AUROC: 0.5234
# Total Length of Dataloader: 9182
# Confusion Matrix String: [2384 2193 2273 2332]
# Test F-Score: 0.5514026401949561
# Test AUROC: 0.5854
# Total Length of Dataloader: 8240
# Confusion Matrix String: [2555 1418 2255 2012]
# Test F-Score: 0.5053642063865952
# Test AUROC: 0.5063
# Total Length of Dataloader: 6500
# Confusion Matrix String: [1614 1674 1540 1672]
# Test F-Score: 0.6057178647883776
# Test AUROC: 0.6434
# Total Length of Dataloader: 7049
# Confusion Matrix String: [1550 1284 1526 2689]
# Error processing /mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/SRF/CNN3/test_results.csv: [Errno 2] No such file or directory: '/mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/SRF/CNN3/test_results.csv'
# Error processing /mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/TCF12/CNN3/test_results.csv: [Errno 2] No such file or directory: '/mnt/raid1/thalassini/home/CNN_results_200_batch_128_chrom/TCF12/CNN3/test_results.csv'
# Test F-Score: 0.520304776013084
# Test AUROC: 0.5307
# Total Length of Dataloader: 4927
# Confusion Matrix String: [1281 1273 1092 1281]
# Test F-Score: 0.5763293468499796
# Test AUROC: 0.6192
# Total Length of Dataloader: 7191
# Confusion Matrix String: [2075 1548 1497 2071]
# Test F-Score: 0.5317846483856927
# Test AUROC: 0.5596
# Total Length of Dataloader: 11373
# Confusion Matrix String: [3618 2063 3202 2490]
# Test F-Score: 0.5383408021534084
# Test AUROC: 0.5561
# Total Length of Dataloader: 11317
# Confusion Matrix String: [3392 2357 2859 2709]
# Test F-Score: 0.6241395609393312
# Test AUROC: 0.6767
# Total Length of Dataloader: 6606
# Confusion Matrix String: [2205  977 1506 1918]
# Test F-Score: 0.5229350420267097
# Test AUROC: 0.5485
# Total Length of Dataloader: 11388
# Confusion Matrix String: [3230 3499 1969 2690]
# Test F-Score: 0.7504800283820184
# Test AUROC: 0.8728
# Total Length of Dataloader: 747
# Confusion Matrix String: [248  33 158 308]

# %%
def plot_results(results, metric):
    tfs = list(results.keys())
    scores = [result[metric] for result in results.values()]

    fig, ax = plt.subplots(figsize=(15, 8))  # Adjust the figsize here

    ax.bar(tfs, scores, color='magenta')  # Set the color
    plt.xlabel('Transcription Factor')
    plt.ylabel(metric)
    plt.title(f'{metric} for each Transcription Factor')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
# Plot F-Score
plot_results(results, 'test_f_score')

# %%
# Plot AUROC
plot_results(results, 'test_auroc')
